# %% [markdown]
# # Task A

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
agr_data = pd.read_csv('Agriculture_data.csv')
agr_data
# Out:
#          Series_reference   Period  Data_value   STATUS   UNITS  MAGNTUDE  \
# 0    SNEA.SG01NAC16P10A11  2007.03         526    FINAL  Dollar         6
# 1    SNEA.SG01NAC16P10A11  2008.03         482    FINAL  Dollar         6
# 2    SNEA.SG01NAC16P10A11  2009.03         404    FINAL  Dollar         6
# 3    SNEA.SG01NAC16P10A11  2010.03         450    FINAL  Dollar         6
# 4    SNEA.SG01NAC16P10A11  2011.03         563    FINAL  Dollar         6
# ..                    ...      ...         ...      ...     ...       ...
# 415  SNEA.SG01NAC16P20A99  2016.03       13549    FINAL  Dollar         6
# 416  SNEA.SG01NAC16P20A99  2017.03       13881    FINAL  Dollar         6
# 417  SNEA.SG01NAC16P20A99  2018.03       14788    FINAL  Dollar         6
# 418  SNEA.SG01NAC16P20A99  2019.03       15773  REVISED  Dollar         6
# 419  SNEA.SG01NAC16P20A99  2020.03       16564    FINAL  Dollar         6
#
#                                 Subject  \
# ...

# %%
agr_data.describe()
# Out:
#             Period    Data_value  MAGNTUDE  Series_title_3  Series_title_4  \
# count   420.000000    420.000000     420.0             0.0             0.0
# mean   2013.530000   2376.026190       6.0             NaN             NaN
# std       4.035936   4840.409542       0.0             NaN             NaN
# min    2007.030000   -244.000000       6.0             NaN             NaN
# 25%    2010.030000    221.000000       6.0             NaN             NaN
# 50%    2013.530000    715.500000       6.0             NaN             NaN
# 75%    2017.030000   2108.250000       6.0             NaN             NaN
# max    2020.030000  30370.000000       6.0             NaN             NaN
#
#        Series_title_5
# count             0.0
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
agr_data['Data_value'] = agr_data['Data_value'].fillna(agr_data['Data_value'].mean())

# %%
agr_data['Series_title_2'] = agr_data['Series_title_2'].fillna(agr_data['Series_title_2'].mode())

# %%
bar = plt.figure(figsize=(22, 11))
x_axis = agr_data['Series_title_2']
y_axis = agr_data['Data_value']

plt.bar(x_axis,y_axis)
plt.title('Bar Chart')
plt.xlabel('Series title 2')
plt.ylabel('Data Value')
plt.show()

# %%
plot = plt.figure(figsize=(22, 11))
x_axis = agr_data['Series_title_2']
y_axis = agr_data['Data_value']

plt.plot(x_axis,y_axis)
plt.title('Plot Chart')
plt.xlabel('Series title 2')
plt.ylabel('Data Value')
plt.show()

# %%
scatter = plt.figure(figsize=(22, 11))
x_axis = agr_data['Series_title_2']
y_axis = agr_data['Data_value']

plt.scatter(x_axis,y_axis)
plt.title('Scatter Plot')
plt.xlabel('Series title 2')
plt.ylabel('Data Value')
plt.show()

# %%
chart = agr_data['Series_title_2'].value_counts()
plt.pie(chart)
plt.title('Pie chart for series title 2')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
chart = agr_data['Data_value'].value_counts()
plt.pie(chart)
plt.title('Pie chart for data values')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Task B

# %%
import csv
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
header = ['Name', 'Age', 'Height', 'Gpa']

with open('Student_data.csv', 'w', newline = '') as file:
    writer = csv.writer(file)
    writer.writerow(header)
    num = 1
    for i in range(1000):
        first_names=('John','Andy','Joe', 'ALi', 'Umar', 'maryam', 'Ayesha', 'usman')
        last_names=num
        Name =" ".join(random.choice(first_names)+" "+str(last_names))
        num = num + 1
        gpa = random.uniform(2.5, 4)
        gpa = round(gpa, 2)
        writer.writerow([Name, (random.randint(18, 24)), (random.randint(60, 75)), gpa])

# %%
stu_data = pd.read_csv('Student_data.csv')
stu_data
# Out:
#                       Name  Age  Height   Gpa
# 0              U m a r   1   20      64  3.08
# 1                A L i   2   20      61  2.95
# 2              J o h n   3   20      67  2.99
# 3                A L i   4   24      60  3.13
# 4              A n d y   5   20      67  3.78
# ..                     ...  ...     ...   ...
# 995        J o h n   9 9 6   24      63  3.93
# 996        U m a r   9 9 7   21      68  3.91
# 997        J o h n   9 9 8   20      74  3.17
# 998        J o h n   9 9 9   22      62  3.83
# 999  m a r y a m   1 0 0 0   24      75  3.33
#
# [1000 rows x 4 columns]

# %%
bar = plt.figure(figsize=(22, 11))
x_axis = stu_data['Name']
y_axis = stu_data['Age']

plt.bar(x_axis,y_axis)
plt.title('Bar Chart for age')
plt.xlabel('Name')
plt.ylabel('Age')
plt.show()

# %%
bar = plt.figure(figsize=(22, 11))
x_axis = stu_data['Name']
y_axis = stu_data['Height']

plt.bar(x_axis,y_axis)
plt.title('Bar Chart for height')
plt.xlabel('Name')
plt.ylabel('height')
plt.show()

# %%
bar = plt.figure(figsize=(22, 11))
x_axis = stu_data['Name']
y_axis = stu_data['Gpa']

plt.bar(x_axis,y_axis)
plt.title('Bar Chart for gpa')
plt.xlabel('Name')
plt.ylabel('gpa')
plt.show()

# %%
plot = plt.figure(figsize=(22, 11))
x_axis = stu_data['Name']
y_axis = stu_data['Age']

plt.plot(x_axis,y_axis)
plt.title('line Chart for age')
plt.xlabel('Name')
plt.ylabel('age')
plt.show()

# %%
plot = plt.figure(figsize=(22, 11))
x_axis = stu_data['Name']
y_axis = stu_data['Height']

plt.plot(x_axis,y_axis)
plt.title('line Chart for height')
plt.xlabel('Name')
plt.ylabel('height')
plt.show()

# %%
plot = plt.figure(figsize=(22, 11))
x_axis = stu_data['Name']
y_axis = stu_data['Gpa']

plt.plot(x_axis,y_axis)
plt.title('line Chart for Gpa')
plt.xlabel('Name')
plt.ylabel('Gpa')
plt.show()

# %% [markdown]
# # Task 3

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.preprocessing import OneHotEncoder
import joblib

# %%
data = pd.read_csv('Student_data.csv')
data['Gpa']=data['Gpa'].astype('category')
data['Gpa']=data['Gpa'].cat.codes
enc=OneHotEncoder()
enc_data=pd.DataFrame(enc.fit_transform(data[['Gpa']]).toarray())
stu_data=data.join(enc_data)

# %%
# load the iris dataset as an example

stu_data = pd.read_csv('Student_data.csv')

# store the feature matrix (X) and response vector (y)
X = np.array(stu_data['Age'])
y = np.array(stu_data['Gpa'])

# splitting X and y into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# training the model on training set
knn = KNeighborsClassifier(n_neighbors=3)
y_train = y_train.astype('int')
knn.fit(X_train.reshape(-1,1), y_train.reshape(-1,1))

# making predictions on the testing set
y_pred = knn.predict(X_test.reshape(-1, 1))

# comparing actual response values (y_test) with predicted response values (y_pred)
y_test = y_test.astype(int)

print("kNN model accuracy : ", metrics.accuracy_score(y_test, y_pred)*100)

# showing predictions
print("So knn Predicted values are : ", y_pred)
# Out:
# kNN model accuracy :  59.0
# So knn Predicted values are :  [2 2 2 3 3 3 2 3 3 3 3 2 3 3 3 3 3 3 3 3 3 3 3 3 2 3 3 3 3 3 3 2 3 3 3 3 3
#  3 3 3 3 3 3 3 2 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 2 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 2 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 2 3 2 2 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 2 3 3 2 2 3 3 3 3 3
#  3 3 2 3 3 2 3 3 3 3 3 3 2 2 3 3 3 3 3 3 3 3 2 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 2 3 2 3 2 3 3 3 3 3 2 3 3 3 3 3 2 3 3 3 3 2 3
#  3 3 3 3 3 3 3 3 3 3 3 2 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 3 2 3 3 3 3 3 3 3 2 2 3 3 3 2 3 3 2 3 3 2 2 3 3
#  3 3 3 3 3 3 3 3 3 3 2 3 3 3 3 3 2 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 2 3
#  3 2 3 3 2 3 3 3 3 3 3 3 3 3 2 3 3 3 3 3 2 3 3 3 2 2 3 3 3 3 3 3 3 3 2 3 2
#  2 3 3 3 3 2 3 2 3 3 2 3 3 3 3 3 3 3 2 3 3 3 3 3 3 3 3 3 3 3]
# ...
